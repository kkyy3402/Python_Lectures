# %% [markdown]
# ### 라이브러리란?
# Library는 도서관이라는 뜻이죠.
# 전세계에 있는 파이썬을 사용하는 사람들이 만들어놓은 **유용한 도구모음**으로 생각해주시면 될 것 같습니다.
# 파이썬에서는 pip라는 도구를 통해 손쉽게 라이브러리를 설치하고 삭제할 수 있습니다.
# 윈도우의 '프로그램 추가/제거' 혹은 리눅스의 'apt'와 비슷한 역할을 한다고 생각해주시면 됩니다.
#
# 이 라이브러리를 통해 크롤링, 데이터 시각화, GUI 프로그래밍, 네트워킹 등 다양한 작업들을 파이썬을 통해 할 수 있습니다.

# %% [markdown]
# ### pip를 통해 라이브러리 설치해보기
# 네트워킹을 할 때 사용하는 라이브러리인 'requests' 라이브러리를 설치해보도록 하겠습니다.
#
# Code 모드로 다음을 입력해주세요.
# !pip3 install requests

# %%
# !pip3 install requests
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\gangyeolkim\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# ...

# %% [markdown]
# Install Successfully ..라는 메시지가 나왔다면 성공적으로 설치가 된 것입니다.

# %% [markdown]
# ### requests 라이브러리 사용해보기
# 라이브러리를 설치했으니, 이제 해당 라이브러리를 사용해보도록 하겠습니다.
# 저는 예시로 네이버 서버에 요청을 해보도록 하겠습니다.

# %%
import requests 

res = requests.get("https://naver.com")
res.text
# Out:
# '\n<!doctype html>                <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양
# ...

# %% [markdown]
# requests 라이브러리가 잘 동작하여
# 우리가 의도한 것처럼 html 데이터를 정상적으로 수신한 것을 확인할 수 있습니다.
